# %%
# Import dependencies
from functools import cache
import jax
import jax.numpy as np
from memo import memo, domain
from enum import IntEnum
import matplotlib.pyplot as plt

# %%
class ACTIONS(IntEnum):
    INITIATE = 0 
    NO_ACTION = 1

class RESPONSES(IntEnum):
    ACCEPT = 0 
    REJECT = 1

class AGENTS(IntEnum):
    ALICE = 0 
    BOB = 1
    CHARLIE = 2
    DAISY = 3
    EMIEL = 4

# %%
@memo 
def generate_data(t):
    alice: chooses(agent in AGENTS, wpp=1)
    alice: chooses(action in ACTIONS, wpp=1)
    alice: chooses(response in RESPONSES, wpp=1)
    return

# %%
generate_data()
# Out:
# Array(1, dtype=int32, weak_type=True)
