# %%
# Inferring internal structure of social collectives paper
data = [(i1, j1, a1), (i2,j2,a2)]

def infer():
    return 1

role_probs = infer(data)
# Out:
# hi

# %%
# Leader / Follower
# Lead / Follow

# Every job has a collective payoff
# Step function of collective payoff

# Inferring internal structure of social collectives paper
data = [
    Job 1: [(t1, lead, follow, follow), (t2, lead, follow, follow)], # collective_payoff = $100
    Job 2: [(t1, lead, follow, lead), (t2, lead, follow, lead)], # collective_payoff = $200
    ]


def infer():
    return 1

role_probs = infer(data)



#----------

#start: 5 agents: 2 leaders(high proactivity), 3 followers, 2 projects
#start: everyone has flat priors of what project to follow.
#step 1: projects become known, agents discuss, the leaders have higher priorrs on whether project 1 or 2 respectuvely works. followers have flat priors. everyine chooses the projects.
#if a project has at kleast 2 workers, it gets carried out
#houses are sold, the money is distributed acciridng to how high the priors where of the project suceeding.
# ths payment is data for the bayesian inference for the next round.
